# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime
import csv

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint george
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | cockburn town
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | matay
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | kabwe
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | cherskiy
# Processing Record 10 of Set 1 | ponta delgada
# Processing Record 11 of Set 1 | stornoway
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | ust-kuyga
# Processing Record 15 of Set 1 | conway
# Processing Record 16 of Set 1 | jiuquan
# Processing Record 17 of Set 1 | mount isa
# Processing Record 18 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | ziyamet
# City not found. Skipping...
# Processing Record 21 of Set 1 | husavik
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | pitimbu
# Processing Record 26 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | atar
# Processing Record 29 of Set 1 | abrau-dyurso
# Processing Record 30 of Set 1 | boende
# Processing Record 31 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | cabo san lucas
# Processing Record 34 of Set 1 | mglin
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | dunmore town
# Processing Record 37 of Set 1 | touros
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | chokurdakh
# Processing Record 40 of Set 1 | mendoza
# Processing Record 41 of Set 1 | shetpe
# Processing Record 42 of Set 1 | zhezkazgan
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | grand gaube
# Processing Record 47 of Set 1 | zeya
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | aklavik
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | plouzane
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | chingirlau
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | vardo
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | chimbote
# Processing Record 9 of Set 2 | barinas
# Processing Record 10 of Set 2 | makat
# Processing Record 11 of Set 2 | saint-leu
# Processing Record 12 of Set 2 | borogontsy
# Processing Record 13 of Set 2 | grand-santi
# Processing Record 14 of Set 2 | cacequi
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 2 | ivaipora
# Processing Record 19 of Set 2 | salamiyah
# Processing Record 20 of Set 2 | ondangwa
# Processing Record 21 of Set 2 | lovozero
# Processing Record 22 of Set 2 | mehamn
# Processing Record 23 of Set 2 | turukhansk
# Processing Record 24 of Set 2 | sept-iles
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | coihaique
# Processing Record 27 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 2 | harbin
# Processing Record 29 of Set 2 | mitsamiouli
# Processing Record 30 of Set 2 | irun
# Processing Record 31 of Set 2 | saint anthony
# Processing Record 32 of Set 2 | zyryanka
# Processing Record 33 of Set 2 | noumea
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | vestmannaeyjar
# Processing Record 36 of Set 2 | ayios kirikos
# City not found. Skipping...
# Processing Record 37 of Set 2 | dunedin
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | avera
# Processing Record 42 of Set 2 | la vega
# Processing Record 43 of Set 2 | buala
# Processing Record 44 of Set 2 | taylor
# Processing Record 45 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | grindavik
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | caravelas
# Processing Record 1 of Set 3 | ilulissat
# Processing Record 2 of Set 3 | la asuncion
# Processing Record 3 of Set 3 | leshukonskoye
# Processing Record 4 of Set 3 | kangaatsiaq
# Processing Record 5 of Set 3 | nigde
# Processing Record 6 of Set 3 | kahului
# Processing Record 7 of Set 3 | melville
# Processing Record 8 of Set 3 | ostrovnoy
# Processing Record 9 of Set 3 | mukhen
# Processing Record 10 of Set 3 | bengkulu
# Processing Record 11 of Set 3 | cape town
# Processing Record 12 of Set 3 | hervey bay
# Processing Record 13 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 3 | pringsewu
# Processing Record 15 of Set 3 | bara
# Processing Record 16 of Set 3 | grass valley
# Processing Record 17 of Set 3 | geraldton
# Processing Record 18 of Set 3 | hasaki
# Processing Record 19 of Set 3 | lompoc
# Processing Record 20 of Set 3 | castro
# Processing Record 21 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 3 | cap malheureux
# Processing Record 23 of Set 3 | shahjahanpur
# Processing Record 24 of Set 3 | sao filipe
# Processing Record 25 of Set 3 | shelburne
# Processing Record 26 of Set 3 | aripuana
# Processing Record 27 of Set 3 | batagay
# Processing Record 28 of Set 3 | amapa
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | los ranchos de albuquerque
# Processing Record 31 of Set 3 | gore
# Processing Record 32 of Set 3 | pisco
# Processing Record 33 of Set 3 | marrakesh
# Processing Record 34 of Set 3 | nyurba
# Processing Record 35 of Set 3 | chokwe
# Processing Record 36 of Set 3 | raudeberg
# Processing Record 37 of Set 3 | turayf
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | waipawa
# Processing Record 40 of Set 3 | saint-pierre
# Processing Record 41 of Set 3 | nola
# Processing Record 42 of Set 3 | kaitangata
# Processing Record 43 of Set 3 | broken hill
# Processing Record 44 of Set 3 | veraval
# Processing Record 45 of Set 3 | tautira
# Processing Record 46 of Set 3 | upernavik
# Processing Record 47 of Set 3 | angoram
# Processing Record 48 of Set 3 | lago da pedra
# Processing Record 49 of Set 3 | hofn
# Processing Record 50 of Set 3 | avarua
# Processing Record 1 of Set 4 | port elizabeth
# Processing Record 2 of Set 4 | the valley
# Processing Record 3 of Set 4 | gisenyi
# Processing Record 4 of Set 4 | hakkari
# Processing Record 5 of Set 4 | kudahuvadhoo
# Processing Record 6 of Set 4 | hithadhoo
# Processing Record 7 of Set 4 | nanortalik
# Processing Record 8 of Set 4 | new norfolk
# Processing Record 9 of Set 4 | qinhuangdao
# Processing Record 10 of Set 4 | vila
# Processing Record 11 of Set 4 | novobirilyussy
# Processing Record 12 of Set 4 | salalah
# Processing Record 13 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 4 | kodiak
# Processing Record 15 of Set 4 | jalingo
# Processing Record 16 of Set 4 | hilo
# Processing Record 17 of Set 4 | tuatapere
# Processing Record 18 of Set 4 | mungwi
# Processing Record 19 of Set 4 | kisangani
# Processing Record 20 of Set 4 | iquique
# Processing Record 21 of Set 4 | luanda
# Processing Record 22 of Set 4 | irtyshskiy
# Processing Record 23 of Set 4 | shenkursk
# Processing Record 24 of Set 4 | severo-kurilsk
# Processing Record 25 of Set 4 | ranong
# Processing Record 26 of Set 4 | taltal
# Processing Record 27 of Set 4 | suarez
# Processing Record 28 of Set 4 | nsukka
# Processing Record 29 of Set 4 | soyo
# Processing Record 30 of Set 4 | at-bashi
# Processing Record 31 of Set 4 | capaci
# Processing Record 32 of Set 4 | lavrentiya
# Processing Record 33 of Set 4 | wewak
# Processing Record 34 of Set 4 | hay river
# Processing Record 35 of Set 4 | yar-sale
# Processing Record 36 of Set 4 | alofi
# Processing Record 37 of Set 4 | suntar
# Processing Record 38 of Set 4 | hammerfest
# Processing Record 39 of Set 4 | chara
# Processing Record 40 of Set 4 | bonavista
# Processing Record 41 of Set 4 | fuzhou
# Processing Record 42 of Set 4 | laguna
# Processing Record 43 of Set 4 | samarai
# Processing Record 44 of Set 4 | sitka
# Processing Record 45 of Set 4 | faya
# Processing Record 46 of Set 4 | itarema
# Processing Record 47 of Set 4 | talnakh
# Processing Record 48 of Set 4 | imeni poliny osipenko
# Processing Record 49 of Set 4 | minden
# Processing Record 50 of Set 4 | kavieng
# Processing Record 1 of Set 5 | ancud
# Processing Record 2 of Set 5 | krasnovishersk
# Processing Record 3 of Set 5 | khatanga
# Processing Record 4 of Set 5 | brandenburg
# Processing Record 5 of Set 5 | fairbanks
# Processing Record 6 of Set 5 | conceicao do araguaia
# Processing Record 7 of Set 5 | clyde river
# Processing Record 8 of Set 5 | lorengau
# Processing Record 9 of Set 5 | zamora
# Processing Record 10 of Set 5 | havoysund
# Processing Record 11 of Set 5 | provideniya
# Processing Record 12 of Set 5 | brandon
# Processing Record 13 of Set 5 | yellowknife
# Processing Record 14 of Set 5 | glubokoe
# City not found. Skipping...
# Processing Record 15 of Set 5 | eyrarbakki
# Processing Record 16 of Set 5 | east london
# Processing Record 17 of Set 5 | sargatskoye
# Processing Record 18 of Set 5 | qaanaaq
# Processing Record 19 of Set 5 | wonthaggi
# Processing Record 20 of Set 5 | varzea grande
# Processing Record 21 of Set 5 | broome
# Processing Record 22 of Set 5 | sosua
# Processing Record 23 of Set 5 | nadym
# Processing Record 24 of Set 5 | guerrero negro
# Processing Record 25 of Set 5 | roald
# Processing Record 26 of Set 5 | souillac
# Processing Record 27 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 5 | richards bay
# Processing Record 29 of Set 5 | orito
# Processing Record 30 of Set 5 | mar del plata
# Processing Record 31 of Set 5 | wilkie
# Processing Record 32 of Set 5 | los cedrales
# Processing Record 33 of Set 5 | konevo
# Processing Record 34 of Set 5 | saldanha
# Processing Record 35 of Set 5 | verkhoshizhemye
# Processing Record 36 of Set 5 | quixere
# Processing Record 37 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 5 | la ronge
# Processing Record 39 of Set 5 | mao
# Processing Record 40 of Set 5 | mandurah
# Processing Record 41 of Set 5 | bainbridge
# Processing Record 42 of Set 5 | leningradskiy
# Processing Record 43 of Set 5 | georgetown
# Processing Record 44 of Set 5 | sao joao da barra
# Processing Record 45 of Set 5 | mandalgovi
# Processing Record 46 of Set 5 | killybegs
# Processing Record 47 of Set 5 | okandja
# City not found. Skipping...
# Processing Record 48 of Set 5 | alpena
# Processing Record 49 of Set 5 | dingle
# Processing Record 50 of Set 5 | eyl
# Processing Record 1 of Set 6 | colac
# Processing Record 2 of Set 6 | kidal
# Processing Record 3 of Set 6 | walvis bay
# Processing Record 4 of Set 6 | yarmouth
# Processing Record 5 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 6 | mount gambier
# Processing Record 7 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 6 | tilichiki
# Processing Record 9 of Set 6 | rawson
# Processing Record 10 of Set 6 | bandipur
# Processing Record 11 of Set 6 | mayo
# Processing Record 12 of Set 6 | quincy
# Processing Record 13 of Set 6 | esperance
# Processing Record 14 of Set 6 | deogarh
# Processing Record 15 of Set 6 | dicabisagan
# Processing Record 16 of Set 6 | yeppoon
# Processing Record 17 of Set 6 | kosum phisai
# Processing Record 18 of Set 6 | waddan
# Processing Record 19 of Set 6 | pacific grove
# Processing Record 20 of Set 6 | quatre cocos
# Processing Record 21 of Set 6 | tiksi
# Processing Record 22 of Set 6 | isangel
# Processing Record 23 of Set 6 | kieta
# Processing Record 24 of Set 6 | batouri
# Processing Record 25 of Set 6 | itoman
# Processing Record 26 of Set 6 | asyut
# Processing Record 27 of Set 6 | marataizes
# Processing Record 28 of Set 6 | ardahan
# Processing Record 29 of Set 6 | kirakira
# Processing Record 30 of Set 6 | dukhovshchina
# Processing Record 31 of Set 6 | raga
# Processing Record 32 of Set 6 | nuuk
# Processing Record 33 of Set 6 | asfi
# Processing Record 34 of Set 6 | along
# Processing Record 35 of Set 6 | komsomolskiy
# Processing Record 36 of Set 6 | ocampo
# Processing Record 37 of Set 6 | yartsevo
# Processing Record 38 of Set 6 | nelson bay
# Processing Record 39 of Set 6 | baoqing
# Processing Record 40 of Set 6 | moyale
# Processing Record 41 of Set 6 | lebu
# Processing Record 42 of Set 6 | kununurra
# Processing Record 43 of Set 6 | fortuna
# Processing Record 44 of Set 6 | serebryansk
# Processing Record 45 of Set 6 | litayen
# City not found. Skipping...
# Processing Record 46 of Set 6 | do gonbadan
# Processing Record 47 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 48 of Set 6 | arlit
# Processing Record 49 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 6 | liverpool
# Processing Record 1 of Set 7 | fort nelson
# Processing Record 2 of Set 7 | haradok
# Processing Record 3 of Set 7 | kenai
# Processing Record 4 of Set 7 | longyearbyen
# Processing Record 5 of Set 7 | carutapera
# Processing Record 6 of Set 7 | borovskoy
# Processing Record 7 of Set 7 | puerto escondido
# Processing Record 8 of Set 7 | astana
# Processing Record 9 of Set 7 | inta
# Processing Record 10 of Set 7 | klamath falls
# Processing Record 11 of Set 7 | piranshahr
# Processing Record 12 of Set 7 | pindobacu
# Processing Record 13 of Set 7 | iqaluit
# Processing Record 14 of Set 7 | namatanai
# Processing Record 15 of Set 7 | mbanza-ngungu
# Processing Record 16 of Set 7 | urucui
# Processing Record 17 of Set 7 | oyama
# Processing Record 18 of Set 7 | ithaca
# Processing Record 19 of Set 7 | sobinka
# Processing Record 20 of Set 7 | port moresby
# Processing Record 21 of Set 7 | miracema do tocantins
# Processing Record 22 of Set 7 | linqiong
# Processing Record 23 of Set 7 | ozernovskiy
# Processing Record 24 of Set 7 | naze
# Processing Record 25 of Set 7 | banda aceh
# Processing Record 26 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 7 | gibsons
# Processing Record 28 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 7 | ahipara
# Processing Record 30 of Set 7 | shimoda
# Processing Record 31 of Set 7 | general pico
# Processing Record 32 of Set 7 | viedma
# Processing Record 33 of Set 7 | los lunas
# Processing Record 34 of Set 7 | colares
# Processing Record 35 of Set 7 | norman wells
# Processing Record 36 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 7 | codrington
# Processing Record 38 of Set 7 | ereymentau
# Processing Record 39 of Set 7 | muli
# Processing Record 40 of Set 7 | lagoa
# Processing Record 41 of Set 7 | touho
# Processing Record 42 of Set 7 | bethel
# Processing Record 43 of Set 7 | yashalta
# Processing Record 44 of Set 7 | meulaboh
# Processing Record 45 of Set 7 | santa isabel do rio negro
# Processing Record 46 of Set 7 | valle de allende
# Processing Record 47 of Set 7 | olinda
# Processing Record 48 of Set 7 | brae
# Processing Record 49 of Set 7 | kingston
# Processing Record 50 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 8 | pevek
# Processing Record 2 of Set 8 | ludvika
# Processing Record 3 of Set 8 | martapura
# Processing Record 4 of Set 8 | bilibino
# Processing Record 5 of Set 8 | boa vista
# Processing Record 6 of Set 8 | khorramabad
# Processing Record 7 of Set 8 | peno
# Processing Record 8 of Set 8 | tazmalt
# Processing Record 9 of Set 8 | olafsvik
# Processing Record 10 of Set 8 | robertsport
# Processing Record 11 of Set 8 | marzuq
# Processing Record 12 of Set 8 | aktash
# Processing Record 13 of Set 8 | kristianstad
# Processing Record 14 of Set 8 | tres picos
# Processing Record 15 of Set 8 | darhan
# Processing Record 16 of Set 8 | luderitz
# Processing Record 17 of Set 8 | khasan
# Processing Record 18 of Set 8 | yulara
# Processing Record 19 of Set 8 | ashington
# Processing Record 20 of Set 8 | victoria
# Processing Record 21 of Set 8 | the pas
# Processing Record 22 of Set 8 | mehran
# Processing Record 23 of Set 8 | dubai
# Processing Record 24 of Set 8 | taitung
# Processing Record 25 of Set 8 | bayir
# Processing Record 26 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 27 of Set 8 | road town
# Processing Record 28 of Set 8 | torbay
# Processing Record 29 of Set 8 | wanxian
# Processing Record 30 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 8 | flinders
# Processing Record 32 of Set 8 | lucea
# Processing Record 33 of Set 8 | ambilobe
# Processing Record 34 of Set 8 | jacareacanga
# Processing Record 35 of Set 8 | tadine
# Processing Record 36 of Set 8 | orel-izumrud
# Processing Record 37 of Set 8 | stepnyak
# Processing Record 38 of Set 8 | luba
# Processing Record 39 of Set 8 | vila franca do campo
# Processing Record 40 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 41 of Set 8 | lac du bonnet
# Processing Record 42 of Set 8 | marystown
# Processing Record 43 of Set 8 | araouane
# Processing Record 44 of Set 8 | ifanadiana
# Processing Record 45 of Set 8 | ankang
# Processing Record 46 of Set 8 | alto piquiri
# Processing Record 47 of Set 8 | pleasanton
# Processing Record 48 of Set 8 | hualmay
# Processing Record 49 of Set 8 | lata
# Processing Record 50 of Set 8 | novopokrovka
# Processing Record 1 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 2 of Set 9 | santa cruz
# Processing Record 3 of Set 9 | margate
# Processing Record 4 of Set 9 | joshimath
# Processing Record 5 of Set 9 | ayacucho
# Processing Record 6 of Set 9 | arman
# Processing Record 7 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 9 | zlotow
# Processing Record 9 of Set 9 | axim
# Processing Record 10 of Set 9 | tomatlan
# Processing Record 11 of Set 9 | saint-augustin
# Processing Record 12 of Set 9 | jalu
# Processing Record 13 of Set 9 | high level
# Processing Record 14 of Set 9 | la union
# Processing Record 15 of Set 9 | kirkwall
# Processing Record 16 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 17 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 18 of Set 9 | manokwari
# Processing Record 19 of Set 9 | karratha
# Processing Record 20 of Set 9 | waitati
# Processing Record 21 of Set 9 | neuquen
# Processing Record 22 of Set 9 | tigil
# Processing Record 23 of Set 9 | orda
# Processing Record 24 of Set 9 | hamilton
# Processing Record 25 of Set 9 | constitucion
# Processing Record 26 of Set 9 | tiznit
# Processing Record 27 of Set 9 | maniitsoq
# Processing Record 28 of Set 9 | borger
# Processing Record 29 of Set 9 | los llanos de aridane
# Processing Record 30 of Set 9 | anuppur
# Processing Record 31 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 9 | yuanping
# Processing Record 33 of Set 9 | develi
# Processing Record 34 of Set 9 | faanui
# Processing Record 35 of Set 9 | oskarshamn
# Processing Record 36 of Set 9 | roblin
# Processing Record 37 of Set 9 | santiago
# Processing Record 38 of Set 9 | kaupanger
# Processing Record 39 of Set 9 | bathsheba
# Processing Record 40 of Set 9 | san patricio
# Processing Record 41 of Set 9 | verkhnyaya inta
# Processing Record 42 of Set 9 | shima
# Processing Record 43 of Set 9 | nome
# Processing Record 44 of Set 9 | hirado
# Processing Record 45 of Set 9 | smithers
# Processing Record 46 of Set 9 | college
# Processing Record 47 of Set 9 | jumla
# Processing Record 48 of Set 9 | allanmyo
# City not found. Skipping...
# Processing Record 49 of Set 9 | pedernales
# Processing Record 50 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 10 | yenagoa
# Processing Record 2 of Set 10 | krasnyy chikoy
# Processing Record 3 of Set 10 | prince rupert
# Processing Record 4 of Set 10 | hit
# Processing Record 5 of Set 10 | baghmara
# Processing Record 6 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 10 | ulaangom
# Processing Record 8 of Set 10 | nipawin
# Processing Record 9 of Set 10 | toumodi
# Processing Record 10 of Set 10 | nikolayevsk-na-amure
# Processing Record 11 of Set 10 | sobolevo
# Processing Record 12 of Set 10 | rovnoye
# Processing Record 13 of Set 10 | zhangjiakou
# Processing Record 14 of Set 10 | pangnirtung
# Processing Record 15 of Set 10 | sao francisco do sul
# Processing Record 16 of Set 10 | katobu
# Processing Record 17 of Set 10 | sabang
# Processing Record 18 of Set 10 | saint-joseph
# Processing Record 19 of Set 10 | novosheshminsk
# Processing Record 20 of Set 10 | puerto baquerizo moreno
# Processing Record 21 of Set 10 | hami
# Processing Record 22 of Set 10 | piacabucu
# Processing Record 23 of Set 10 | linchuan
# City not found. Skipping...
# Processing Record 24 of Set 10 | pionerskiy
# Processing Record 25 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 10 | puerto madryn
# Processing Record 27 of Set 10 | sistranda
# Processing Record 28 of Set 10 | maloy
# Processing Record 29 of Set 10 | fuerte olimpo
# Processing Record 30 of Set 10 | oranjemund
# Processing Record 31 of Set 10 | muros
# Processing Record 32 of Set 10 | duku
# Processing Record 33 of Set 10 | pizarro
# Processing Record 34 of Set 10 | berlevag
# Processing Record 35 of Set 10 | fasa
# Processing Record 36 of Set 10 | vaitape
# Processing Record 37 of Set 10 | manchester
# Processing Record 38 of Set 10 | sacalaseni
# City not found. Skipping...
# Processing Record 39 of Set 10 | puerto penasco
# Processing Record 40 of Set 10 | yaan
# Processing Record 41 of Set 10 | devrek
# Processing Record 42 of Set 10 | yarkovo
# Processing Record 43 of Set 10 | kadaya
# Processing Record 44 of Set 10 | muscatine
# Processing Record 45 of Set 10 | natchez
# Processing Record 46 of Set 10 | nerang
# Processing Record 47 of Set 10 | mokolo
# Processing Record 48 of Set 10 | ulukulevo
# Processing Record 49 of Set 10 | te anau
# Processing Record 50 of Set 10 | warragul
# Processing Record 1 of Set 11 | tarabuco
# Processing Record 2 of Set 11 | sulangan
# Processing Record 3 of Set 11 | bloemhof
# Processing Record 4 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 11 | sikonge
# Processing Record 6 of Set 11 | havelock
# Processing Record 7 of Set 11 | camocim
# Processing Record 8 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 9 of Set 11 | kwinana
# Processing Record 10 of Set 11 | adrar
# Processing Record 11 of Set 11 | port hedland
# Processing Record 12 of Set 11 | tecpan
# Processing Record 13 of Set 11 | skovorodino
# Processing Record 14 of Set 11 | kurilsk
# Processing Record 15 of Set 11 | yomou
# Processing Record 16 of Set 11 | camacha
# Processing Record 17 of Set 11 | jinxiang
# Processing Record 18 of Set 11 | waslala
# Processing Record 19 of Set 11 | charters towers
# Processing Record 20 of Set 11 | quelimane
# Processing Record 21 of Set 11 | kruisfontein
# Processing Record 22 of Set 11 | porto novo
# Processing Record 23 of Set 11 | pozo colorado
# Processing Record 24 of Set 11 | ornskoldsvik
# Processing Record 25 of Set 11 | alugan
# Processing Record 26 of Set 11 | pyaozerskiy
# Processing Record 27 of Set 11 | dawson
# Processing Record 28 of Set 11 | menongue
# Processing Record 29 of Set 11 | klaksvik
# Processing Record 30 of Set 11 | rehoboth
# Processing Record 31 of Set 11 | kingsland
# Processing Record 32 of Set 11 | srednekolymsk
# Processing Record 33 of Set 11 | ixtapa
# Processing Record 34 of Set 11 | kerema
# Processing Record 35 of Set 11 | san cristobal
# Processing Record 36 of Set 11 | tabou
# Processing Record 37 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 11 | dmitriyevka
# Processing Record 39 of Set 11 | tatvan
# Processing Record 40 of Set 11 | nemuro
# Processing Record 41 of Set 11 | beloha
# Processing Record 42 of Set 11 | belaya gora
# Processing Record 43 of Set 11 | ambon
# Processing Record 44 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 45 of Set 11 | yarim
# Processing Record 46 of Set 11 | coahuayana
# Processing Record 47 of Set 11 | nioro
# Processing Record 48 of Set 11 | homer
# Processing Record 49 of Set 11 | rudbar
# Processing Record 50 of Set 11 | mormugao
# Processing Record 1 of Set 12 | pangai
# Processing Record 2 of Set 12 | kpandae
# Processing Record 3 of Set 12 | mutata
# Processing Record 4 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 12 | altay
# Processing Record 6 of Set 12 | bunia
# Processing Record 7 of Set 12 | sorong
# Processing Record 8 of Set 12 | taree
# Processing Record 9 of Set 12 | inuvik
# Processing Record 10 of Set 12 | villarrica
# Processing Record 11 of Set 12 | lasa
# Processing Record 12 of Set 12 | puerto santander
# Processing Record 13 of Set 12 | graham
# Processing Record 14 of Set 12 | porto velho
# Processing Record 15 of Set 12 | katsuura
# Processing Record 16 of Set 12 | sambava
# Processing Record 17 of Set 12 | chaadayevka
# Processing Record 18 of Set 12 | doka
# Processing Record 19 of Set 12 | el retorno
# Processing Record 20 of Set 12 | half moon bay
# Processing Record 21 of Set 12 | koronowo
# Processing Record 22 of Set 12 | ayagoz
# Processing Record 23 of Set 12 | dzhebariki-khaya
# Processing Record 24 of Set 12 | bandarbeyla
# Processing Record 25 of Set 12 | pangody
# Processing Record 26 of Set 12 | somerset
# Processing Record 27 of Set 12 | scarborough
# Processing Record 28 of Set 12 | san francisco
# Processing Record 29 of Set 12 | palmer
# Processing Record 30 of Set 12 | nisia floresta
# Processing Record 31 of Set 12 | keti bandar
# Processing Record 32 of Set 12 | oranjestad
# Processing Record 33 of Set 12 | shushenskoye
# Processing Record 34 of Set 12 | fajardo
# Processing Record 35 of Set 12 | alcantara
# Processing Record 36 of Set 12 | coquimbo
# Processing Record 37 of Set 12 | bowen
# Processing Record 38 of Set 12 | vestmanna
# Processing Record 39 of Set 12 | bundaberg
# Processing Record 40 of Set 12 | galle
# Processing Record 41 of Set 12 | makung
# City not found. Skipping...
# Processing Record 42 of Set 12 | chicama
# Processing Record 43 of Set 12 | aksarka
# Processing Record 44 of Set 12 | tura
# Processing Record 45 of Set 12 | maceio
# Processing Record 46 of Set 12 | deer lake
# Processing Record 47 of Set 12 | belmonte
# Processing Record 48 of Set 12 | sekoma
# Processing Record 49 of Set 12 | alice springs
# Processing Record 50 of Set 12 | la libertad
# Processing Record 1 of Set 13 | odienne
# Processing Record 2 of Set 13 | benghazi
# Processing Record 3 of Set 13 | tahoua
# Processing Record 4 of Set 13 | huallanca
# Processing Record 5 of Set 13 | tornio
# Processing Record 6 of Set 13 | tonj
# Processing Record 7 of Set 13 | markova
# Processing Record 8 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 13 | handan
# Processing Record 10 of Set 13 | goiania
# Processing Record 11 of Set 13 | praia da vitoria
# Processing Record 12 of Set 13 | xai-xai
# Processing Record 13 of Set 13 | acajutla
# Processing Record 14 of Set 13 | santo tomas
# Processing Record 15 of Set 13 | saint-francois
# Processing Record 16 of Set 13 | kavaratti
# Processing Record 17 of Set 13 | egvekinot
# Processing Record 18 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 13 | arona
# Processing Record 20 of Set 13 | nakusp
# Processing Record 21 of Set 13 | narsaq
# Processing Record 22 of Set 13 | qasigiannguit
# Processing Record 23 of Set 13 | kupang
# Processing Record 24 of Set 13 | nouadhibou
# Processing Record 25 of Set 13 | chavantes
# Processing Record 26 of Set 13 | linda
# Processing Record 27 of Set 13 | port hardy
# Processing Record 28 of Set 13 | cayenne
# Processing Record 29 of Set 13 | clevelandia
# Processing Record 30 of Set 13 | klaeng
# Processing Record 31 of Set 13 | vostok
# Processing Record 32 of Set 13 | buraydah
# Processing Record 33 of Set 13 | yuty
# Processing Record 34 of Set 13 | magui
# City not found. Skipping...
# Processing Record 35 of Set 13 | berbera
# Processing Record 36 of Set 13 | zetel
# Processing Record 37 of Set 13 | shirokiy
# Processing Record 38 of Set 13 | borovoy
# Processing Record 39 of Set 13 | toritama
# Processing Record 40 of Set 13 | rutul
# Processing Record 41 of Set 13 | saint-denis
# Processing Record 42 of Set 13 | tazovskiy
# Processing Record 43 of Set 13 | chitral
# Processing Record 44 of Set 13 | sungaipenuh
# Processing Record 45 of Set 13 | hazleton
# Processing Record 46 of Set 13 | campbellsville
# Processing Record 47 of Set 13 | west des moines
# Processing Record 48 of Set 13 | popondetta
# Processing Record 49 of Set 13 | gongzhuling
# Processing Record 50 of Set 13 | inhambane
# Processing Record 1 of Set 14 | tateyama
# Processing Record 2 of Set 14 | la palma
# Processing Record 3 of Set 14 | pangkalanbuun
# Processing Record 4 of Set 14 | inyonga
# Processing Record 5 of Set 14 | asau
# Processing Record 6 of Set 14 | neiafu
# Processing Record 7 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 14 | port lincoln
# Processing Record 9 of Set 14 | travesia
# Processing Record 10 of Set 14 | jasper
# Processing Record 11 of Set 14 | balkanabat
# Processing Record 12 of Set 14 | lethem
# Processing Record 13 of Set 14 | kichera
# Processing Record 14 of Set 14 | necochea
# Processing Record 15 of Set 14 | maebaru
# Processing Record 16 of Set 14 | kijang
# Processing Record 17 of Set 14 | botwood
# Processing Record 18 of Set 14 | corinto
# Processing Record 19 of Set 14 | tabuk
# Processing Record 20 of Set 14 | marsh harbour
# Processing Record 21 of Set 14 | whitehorse
# Processing Record 22 of Set 14 | burewala
# Processing Record 23 of Set 14 | auki
# Processing Record 24 of Set 14 | shache
# Processing Record 25 of Set 14 | penhold
# Processing Record 26 of Set 14 | tambul
# City not found. Skipping...
# Processing Record 27 of Set 14 | selikhino
# Processing Record 28 of Set 14 | san jose de buan
# Processing Record 29 of Set 14 | jackson
# Processing Record 30 of Set 14 | sydney
# Processing Record 31 of Set 14 | selma
# Processing Record 32 of Set 14 | iskateley
# Processing Record 33 of Set 14 | praia
# Processing Record 34 of Set 14 | nekhayevskiy
# Processing Record 35 of Set 14 | kerzhenets
# City not found. Skipping...
# Processing Record 36 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 14 | clifton
# Processing Record 38 of Set 14 | moroni
# Processing Record 39 of Set 14 | srivardhan
# Processing Record 40 of Set 14 | vuktyl
# Processing Record 41 of Set 14 | alta floresta
# Processing Record 42 of Set 14 | pakxan
# Processing Record 43 of Set 14 | ondjiva
# Processing Record 44 of Set 14 | seoul
# Processing Record 45 of Set 14 | mogadishu
# Processing Record 46 of Set 14 | aasiaat
# Processing Record 47 of Set 14 | sai buri
# Processing Record 48 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 49 of Set 14 | chumikan
# Processing Record 50 of Set 14 | pandegelang
# Processing Record 1 of Set 15 | the hammocks
# Processing Record 2 of Set 15 | byron bay
# Processing Record 3 of Set 15 | peniche
# Processing Record 4 of Set 15 | tucupita
# Processing Record 5 of Set 15 | jefferson city
# Processing Record 6 of Set 15 | pineville
# Processing Record 7 of Set 15 | bentiu
# Processing Record 8 of Set 15 | henties bay
# Processing Record 9 of Set 15 | port-gentil
# Processing Record 10 of Set 15 | zhuanghe
# Processing Record 11 of Set 15 | ekuvukeni
# Processing Record 12 of Set 15 | aden
# Processing Record 13 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 14 of Set 15 | zhanjiang
# Processing Record 15 of Set 15 | kaeo
# Processing Record 16 of Set 15 | teahupoo
# Processing Record 17 of Set 15 | syracuse
# Processing Record 18 of Set 15 | knysna
# Processing Record 19 of Set 15 | qaqortoq
# Processing Record 20 of Set 15 | eloy
# Processing Record 21 of Set 15 | ayan
# Processing Record 22 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 15 | sidney
# Processing Record 25 of Set 15 | nancha
# Processing Record 26 of Set 15 | labrea
# Processing Record 27 of Set 15 | bilma
# Processing Record 28 of Set 15 | qandala
# Processing Record 29 of Set 15 | rupert
# Processing Record 30 of Set 15 | chanika
# Processing Record 31 of Set 15 | pierre
# Processing Record 32 of Set 15 | opuwo
# Processing Record 33 of Set 15 | sola
# Processing Record 34 of Set 15 | ciudad bolivar
# Processing Record 35 of Set 15 | volksrust
# Processing Record 36 of Set 15 | pimampiro
# Processing Record 37 of Set 15 | korla
# Processing Record 38 of Set 15 | chupa
# Processing Record 39 of Set 15 | union
# Processing Record 40 of Set 15 | vao
# Processing Record 41 of Set 15 | gushikawa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Saint George  37.1041 -113.5841     50.47        28           0
# 1        Rikitea -23.1203 -134.9692     78.46        71           9
# 2  Cockburn Town  21.4612  -71.1419     75.67        69           0
# 3          Airai  -8.9266  125.4092     60.12        90          99
# 4          Matay  28.4190   30.7792     57.83        47          94
# 5         Albany  42.6001  -73.9662     26.91        87         100
# 6          Kabwe -14.4469   28.4464     63.79        95         100
# 7          Bluff -46.6000  168.3333     50.58        63          77
# 8       Cherskiy  68.7500  161.3000    -34.71        99          14
# 9  Ponta Delgada  37.7333  -25.6667     62.51        67          20
#
#    Wind Speed Country Current Description
# 0        3.00      US           clear sky
# 1       10.63      PF           clear sky
# 2       15.84      TC           clear sky
# 3        1.86      TL     overcast clouds
# 4       11.07      EG     overcast clouds
# 5        1.01      US          light snow
# 6        4.27      ZM     overcast clouds
# 7        6.78      NZ       broken clouds
# 8        3.15      RU          few clouds
# 9       11.50      PT          few clouds

# %%
#rearrange the column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]

# %%
#check the columns are in the correct order
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Saint George      US  37.1041 -113.5841     50.47        28           0
# 1        Rikitea      PF -23.1203 -134.9692     78.46        71           9
# 2  Cockburn Town      TC  21.4612  -71.1419     75.67        69           0
# 3          Airai      TL  -8.9266  125.4092     60.12        90          99
# 4          Matay      EG  28.4190   30.7792     57.83        47          94
# 5         Albany      US  42.6001  -73.9662     26.91        87         100
# 6          Kabwe      ZM -14.4469   28.4464     63.79        95         100
# 7          Bluff      NZ -46.6000  168.3333     50.58        63          77
# 8       Cherskiy      RU  68.7500  161.3000    -34.71        99          14
# 9  Ponta Delgada      PT  37.7333  -25.6667     62.51        67          20
#
#    Wind Speed Current Description
# 0        3.00           clear sky
# 1       10.63           clear sky
# 2       15.84           clear sky
# 3        1.86     overcast clouds
# 4       11.07     overcast clouds
# 5        1.01          light snow
# 6        4.27     overcast clouds
# 7        6.78       broken clouds
# 8        3.15          few clouds
# 9       11.50          few clouds

# %%
# Assign a variable to save the file and then write the dataframe to a csv file in the current folder.
file_to_save = "WeatherPy_Database.csv"
city_data_df.to_csv(file_to_save)
